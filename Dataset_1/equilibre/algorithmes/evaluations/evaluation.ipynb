# %%
import pandas as pd

# Importez les trois datasets depuis leurs fichiers CSV respectifs
data1 = pd.read_csv('knn_results.csv')
data2 = pd.read_csv('svm_results.csv')
data3 = pd.read_csv('lr_results.csv')
data4 = pd.read_csv('randfor_results.csv')
data5 = pd.read_csv('dnn_results.csv')
data6 = pd.read_csv('cnn_results.csv')
data7 = pd.read_csv('blstm_results.csv')

# Concaténez les trois DataFrames en un seul
all_data = pd.concat([data1, data2, data3, data4, data5, data6, data7 ], ignore_index=True)

# Affichez le DataFrame résultant
all_data.head(n=10)
# Out:
#                            Model  Accuracy  Precision    Recall  F1 Score  \
# 0                            KNN  0.951309   0.948052  0.957092  0.952550
# 1                            SVM  0.789714   0.730931  0.930870  0.818873
# 2            Logistic Regression  0.811321   0.826543  0.797974  0.812007
# 3                  Random forest  0.987219   0.981176  0.994041  0.987567
# 4           Deep neurual network  0.964394   0.954043  0.977354  0.965558
# 5  convolutional neurual network  0.961351   0.938879  0.988677  0.963135
# 6                          BLSTM  0.934571   0.951822  0.918355  0.934789
#
#         AUC
# 0  0.951183
# 1  0.786642
# 2  0.811611
# 3  0.987070
# 4  0.964112
# 5  0.960756
# 6  0.934924
