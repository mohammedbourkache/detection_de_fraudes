# %%
#comparaison des différentes modeles :

# %%
import pandas as pd

data = pd.read_csv('evaluation_final.csv')

# %%
df = data.copy()

# %%
df
# Out:
#                             Model  Accuracy  Precision    Recall  F1 Score  \
# 0                             KNN  0.991870   0.863878  0.800123  0.830779
# 1                             SVM  0.983754   0.984615  0.354244  0.521031
# 2             Logistic Regression  0.763281   0.000217  0.001845  0.000389
# 3                   Random forest  0.994938   0.936070  0.855474  0.893959
# 4                  Decision tree   0.995827   0.909311  0.924969  0.917073
# 5                         XGBoost  0.996211   0.936116  0.910209  0.922981
# 6            Deep neurual network  0.992775   0.927461  0.770603  0.841787
# 7   convolutional neurual network  0.993818   0.933381  0.809963  0.867303
# 8                           BLSTM  0.991133   0.818735  0.827798  0.823242
#
#         AUC
# 0  0.898449
# 1  0.677051
# 2  0.392302
# 3  0.926989
# 4  0.961305
# 5  0.954310
# 6  0.884530
# 7  0.904242
# 8  0.911555

# %%
import matplotlib.pyplot as plt
import numpy as np

# Liste des noms des modèles
model_names = df["Model"]

# Métriques à afficher
metrics = ["Accuracy", "Precision", "Recall", "F1 Score", "AUC"]

# Largeur des barres
bar_width = 0.15

# Position des barres sur l'axe des x
index = np.arange(len(model_names))

# Créer la figure en spécifiant la taille
plt.figure(figsize=(12, 6))  # Ajustez la taille selon vos préférences

# Créer les barres pour chaque métrique
for i, metric in enumerate(metrics):
    values = df[metric]
    plt.bar(index + i * bar_width, values, bar_width, label=metric)

# Définir les étiquettes des modèles sur l'axe des x avec rotation
plt.xlabel('Modèles')
plt.ylabel('Scores')
plt.title('Comparaison des modèles par métrique')
plt.xticks(index + bar_width * (len(metrics) - 1) / 2, model_names, rotation=45)  # Rotation personnalisée ici

# Ajouter les valeurs au-dessus des barres avec une taille de police réduite et des valeurs arrondies
for i, metric in enumerate(metrics):
    values = df[metric]
    for j, v in enumerate(values):
        plt.text(index[j] + i * bar_width, v + 0.01, f'{v:.2f}', fontsize=5.5, ha='center', va='bottom')

# Afficher la légende avec une taille de police réduite
plt.legend(fontsize=6)

# Enregistrer le graphique au format PDF
plt.tight_layout()
plt.savefig('comparaison_ds1_deseq.pdf', format='pdf')

# Afficher le graphique
plt.show()
